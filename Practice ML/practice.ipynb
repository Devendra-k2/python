# %%
print("hello")
print(10+20)
# Out:
# hello
# 30

# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(a)
# Out:
# [1 2 3 4 5]

# %%
print(type(a))
print(np.ndim(a))
# Out:
# <class 'numpy.ndarray'>
# 1

# %%
a=[1,2,3,4]
b=[3,4,5,6]
# c=np.array(a)
# d=np.array(b)
c=np.array([a,b])

print(c)
# Out:
# [[1 2 3 4]
#  [3 4 5 6]]
