# %% [markdown]
# CSV file  practice and parameters

# %%
print("hello")
# Out:
# hello

# %%
# import pandas as pd

# data=pd.read_csv("Environment_Temperature.csv",
#                  encoding="ISO-8859-1",
#                  on_bad_lines='skip',
#                  engine="python"
#                  )

# data.head()
# Out:
# Ó QøZÿÿÿÿÿÿÿÿ4Environment_Temperature_change_E_All_Data_NOFLAG.csv}|_p
# ì½Í  \
# 0                                         ÛgÃöÙ°}6l
# 1                                         ÛgÃöÙ°}6l
# 2  Ëÿþ¿½Ä×ßÿ¿üçï~øÓ¿ýüÝëµõ&ÖýÝw?üòÝOÿs
# m
# ø...
# 3  RòípÒ£­=PyõPæý¯÷Ú´*ùóú=øÉ5Ï/0r¹ÊKgÄyÓ¦...
# 4                                       ^tÐkôè!v2ë
#
#   Gr¥¹y\g¨ý/kº§a÷3YEL±D(Ò/RÏ18naz>/DÞôHÜË`µ8\t
# ÃÃü'  \
# 0                                                NaN
# 1                                                NaN
# 2  óR®?kµê/¬-Ólæ_t0}w~òxìùêÊµ®}éæ·æÈñ~r...
# 3                                                NaN
# 4                                                NaN
#
#   ©
# =ªúû¾ÿîwÿåÇúþuX¯ÿã?ÿó¿½
# x³_ÿÏ?ÿ/ßÿðóÛ±Û¼þß?üéç×ÿ'  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# ...

# %%
import pandas as pd 

url="https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"

data = pd.read_csv(url,chunksize=200)

for chunks in data:
    print(chunks)
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 195  0.01381  80.0   0.46     0  0.422  7.875  32.0  5.6484    4  255
# 196  0.04011  80.0   1.52     0  0.404  7.287  34.1  7.3090    2  329
# 197  0.04666  80.0   1.52     0  0.404  7.107  36.6  7.3090    2  329
# 198  0.03768  80.0   1.52     0  0.404  7.274  38.3  7.3090    2  329
# 199  0.03150  95.0   1.47     0  0.403  6.975  15.3  7.6534    3  402
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...
